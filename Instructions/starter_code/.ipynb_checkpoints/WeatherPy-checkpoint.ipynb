# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
latitude = []
longitude = []
max_temperature = []
humidity_pct = []
cloudiness_pct = []
wind_speed_mph = []
origin = []
date = []
new_cities = []
units = "imperial"
count = 0

for city in cities:
    url = f"{base_url}appid={weather_api_key}&units={units}&q={city}"
    response = requests.get(url).json()
    
    try:
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temperature.append(response["main"]["temp_max"])
        humidity_pct.append(response["main"]["humidity"])
        cloudiness_pct.append(response["clouds"]["all"])
        wind_speed_mph.append(response["wind"]["speed"])
        origin.append(response["sys"]["country"])
        date.append(response["dt"])
        new_cities.append(city)
        count = count + 1
        print(f"Processing city {count}: {city}")
    except KeyError:
        print(f"City not found, skipping {city}")
# Out:
# City not found, skipping palabuhanratu
# City not found, skipping belushya guba
# Processing city 1: clyde river
# Processing city 2: ancud
# Processing city 3: puerto ayora
# City not found, skipping sentyabrskiy
# Processing city 4: geraldton
# Processing city 5: shu
# Processing city 6: chuy
# Processing city 7: wiarton
# Processing city 8: hobart
# Processing city 9: khatanga
# Processing city 10: busselton
# Processing city 11: ushuaia
# Processing city 12: provideniya
# Processing city 13: chokurdakh
# City not found, skipping nizhneyansk
# Processing city 14: itoman
# Processing city 15: puerto lleras
# Processing city 16: komsomolskiy
# Processing city 17: talnakh
# Processing city 18: cidreira
# Processing city 19: narsaq
# Processing city 20: fairbanks
# Processing city 21: port elizabeth
# Processing city 22: sorland
# Processing city 23: tevaitoa
# Processing city 24: benghazi
# Processing city 25: olafsvik
# Processing city 26: vaini
# Processing city 27: kahului
# Processing city 28: barrow
# Processing city 29: yuli
# Processing city 30: punta arenas
# Processing city 31: bluff
# Processing city 32: esperance
# Processing city 33: ipil
# City not found, skipping mentok
# Processing city 34: albany
# Processing city 35: kapaa
# Processing city 36: aksu
# Processing city 37: codrington
# Processing city 38: atuona
# Processing city 39: caravelas
# Processing city 40: mataura
# Processing city 41: ilulissat
# Processing city 42: ingham
# Processing city 43: castro
# Processing city 44: plettenberg bay
# City not found, skipping umzimvubu
# Processing city 45: saskylakh
# Processing city 46: boyolangu
# Processing city 47: qinhuangdao
# City not found, skipping taolanaro
# Processing city 48: islamkot
# Processing city 49: tuktoyaktuk
# Processing city 50: saint-pierre
# Processing city 51: dikson
# Processing city 52: dakar
# Processing city 53: bredasdorp
# Processing city 54: maraa
# Processing city 55: vardo
# Processing city 56: mar del plata
# Processing city 57: beyneu
# Processing city 58: vestmannaeyjar
# Processing city 59: hasaki
# Processing city 60: nanortalik
# Processing city 61: ngong
# City not found, skipping saleaula
# Processing city 62: jamestown
# Processing city 63: kualakapuas
# Processing city 64: bat khela
# Processing city 65: butaritari
# Processing city 66: hobyo
# Processing city 67: tabou
# Processing city 68: port alfred
# Processing city 69: imeni poliny osipenko
# City not found, skipping uwayl
# Processing city 70: dalhousie
# Processing city 71: nikolskoye
# Processing city 72: georgetown
# Processing city 73: cherskiy
# Processing city 74: ixtapa
# Processing city 75: severo-kurilsk
# Processing city 76: eureka
# Processing city 77: innisfail
# Processing city 78: anda
# City not found, skipping mys shmidta
# Processing city 79: homer
# Processing city 80: sistranda
# Processing city 81: rikitea
# City not found, skipping pilao arcado
# Processing city 82: lebu
# Processing city 83: bata
# Processing city 84: katsuura
# Processing city 85: kruisfontein
# City not found, skipping amderma
# Processing city 86: tiksi
# Processing city 87: bonfim
# Processing city 88: ponta do sol
# Processing city 89: mezen
# Processing city 90: hithadhoo
# Processing city 91: kidal
# Processing city 92: omsukchan
# Processing city 93: alofi
# City not found, skipping illoqqortoormiut
# City not found, skipping lolua
# Processing city 94: nizhniy kuranakh
# Processing city 95: kaitangata
# Processing city 96: sahuaripa
# Processing city 97: fernley
# Processing city 98: inhambane
# Processing city 99: grindavik
# Processing city 100: new norfolk
# Processing city 101: boden
# Processing city 102: saint anthony
# Processing city 103: samarai
# Processing city 104: souillac
# Processing city 105: atasu
# Processing city 106: charlestown
# Processing city 107: port hardy
# Processing city 108: villa carlos paz
# Processing city 109: arraial do cabo
# Processing city 110: thompson
# Processing city 111: mount isa
# Processing city 112: isangel
# Processing city 113: kodiak
# Processing city 114: mount gambier
# Processing city 115: lata
# Processing city 116: kamina
# Processing city 117: verkhnyaya inta
# City not found, skipping kazalinsk
# Processing city 118: nhulunbuy
# Processing city 119: botwood
# Processing city 120: yulara
# Processing city 121: praxedis guerrero
# Processing city 122: dingle
# Processing city 123: bethel
# Processing city 124: chongwe
# Processing city 125: upernavik
# Processing city 126: burns lake
# Processing city 127: mumford
# Processing city 128: takoradi
# Processing city 129: auki
# Processing city 130: sobolevo
# Processing city 131: kopervik
# Processing city 132: sisimiut
# Processing city 133: rabo de peixe
# Processing city 134: smithers
# Processing city 135: sept-iles
# Processing city 136: bambous virieux
# City not found, skipping marcona
# Processing city 137: bokhan
# Processing city 138: svencionys
# Processing city 139: bengkulu
# Processing city 140: amapa
# Processing city 141: ambovombe
# Processing city 142: gryazovets
# Processing city 143: bonavista
# Processing city 144: dukat
# Processing city 145: araxa
# Processing city 146: cabo san lucas
# Processing city 147: torbay
# Processing city 148: constitucion
# City not found, skipping karamay
# Processing city 149: xuddur
# Processing city 150: beinamar
# Processing city 151: kavaratti
# Processing city 152: snihurivka
# Processing city 153: sinnamary
# Processing city 154: ayutla
# Processing city 155: kitimat
# Processing city 156: dunedin
# Processing city 157: qaanaaq
# Processing city 158: mattru
# Processing city 159: itacarambi
# Processing city 160: avarua
# Processing city 161: marathon
# Processing city 162: taoudenni
# Processing city 163: nelson bay
# Processing city 164: dharchula
# Processing city 165: hilo
# Processing city 166: yellowknife
# Processing city 167: mao
# Processing city 168: tomatlan
# Processing city 169: morgan city
# Processing city 170: iqaluit
# Processing city 171: teguise
# Processing city 172: hermanus
# Processing city 173: sola
# City not found, skipping balaytigui
# Processing city 174: kieta
# Processing city 175: qasigiannguit
# Processing city 176: ribeira grande
# Processing city 177: longyearbyen
# Processing city 178: pa sang
# Processing city 179: angoram
# Processing city 180: zhezkazgan
# Processing city 181: tasiilaq
# Processing city 182: san carlos de bariloche
# Processing city 183: shubarshi
# Processing city 184: ahuimanu
# Processing city 185: korla
# City not found, skipping makrikhorion
# City not found, skipping piedras amarillas
# Processing city 186: vanimo
# Processing city 187: tubmanburg
# Processing city 188: lakselv
# Processing city 189: liverpool
# Processing city 190: lufilufi
# Processing city 191: nortelandia
# Processing city 192: muzhi
# Processing city 193: padang
# Processing city 194: solnechnyy
# City not found, skipping bengkalis
# Processing city 195: glendive
# City not found, skipping inderborskiy
# Processing city 196: kailua
# Processing city 197: dicabisagan
# Processing city 198: ormara
# Processing city 199: tabuk
# Processing city 200: rumoi
# City not found, skipping barentsburg
# Processing city 201: saint-philippe
# Processing city 202: klyuchi
# Processing city 203: brokopondo
# City not found, skipping karkaralinsk
# Processing city 204: muri
# Processing city 205: sao joao da barra
# Processing city 206: lima
# Processing city 207: santa rosa
# Processing city 208: cape town
# City not found, skipping tumannyy
# Processing city 209: san patricio
# Processing city 210: meulaboh
# Processing city 211: pringsewu
# Processing city 212: stokmarknes
# Processing city 213: chitrakonda
# Processing city 214: kalaleh
# Processing city 215: lompoc
# Processing city 216: naujamiestis
# Processing city 217: zhigansk
# Processing city 218: port-gentil
# Processing city 219: aksarka
# Processing city 220: stabat
# Processing city 221: el alto
# Processing city 222: punta de bombon
# Processing city 223: ugoofaaru
# Processing city 224: dalbandin
# Processing city 225: khingansk
# Processing city 226: mugur-aksy
# Processing city 227: cayenne
# Processing city 228: koutiala
# City not found, skipping olymskiy
# Processing city 229: salalah
# Processing city 230: kavieng
# Processing city 231: luderitz
# Processing city 232: mandalgovi
# Processing city 233: wardha
# Processing city 234: abashiri
# Processing city 235: bambanglipuro
# Processing city 236: alakurtti
# Processing city 237: mongo
# Processing city 238: malinovskiy
# Processing city 239: ukiah
# Processing city 240: lavrentiya
# Processing city 241: gizo
# Processing city 242: togur
# Processing city 243: oparino
# Processing city 244: banda aceh
# Processing city 245: carutapera
# Processing city 246: pisco
# Processing city 247: papara
# Processing city 248: astana
# Processing city 249: beloha
# Processing city 250: tuatapere
# Processing city 251: broome
# Processing city 252: tura
# City not found, skipping barbar
# Processing city 253: tual
# Processing city 254: east london
# Processing city 255: vostok
# Processing city 256: airai
# Processing city 257: port blair
# Processing city 258: gat
# Processing city 259: srednekolymsk
# Processing city 260: gushikawa
# Processing city 261: noyabrsk
# Processing city 262: zhangjiakou
# Processing city 263: jamame
# Processing city 264: mahebourg
# Processing city 265: saldanha
# Processing city 266: boende
# Processing city 267: rosetta
# City not found, skipping phan rang
# Processing city 268: fortuna
# Processing city 269: bembereke
# Processing city 270: namibe
# Processing city 271: lagoa
# Processing city 272: yumen
# Processing city 273: canakkale
# Processing city 274: aguazul
# Processing city 275: brae
# Processing city 276: port pirie
# Processing city 277: kamenskiy
# Processing city 278: inirida
# Processing city 279: palora
# Processing city 280: puerto escondido
# City not found, skipping babanusah
# Processing city 281: kuntaur
# Processing city 282: kulhudhuffushi
# Processing city 283: nara
# City not found, skipping gurskoye
# Processing city 284: coos bay
# Processing city 285: deputatskiy
# Processing city 286: yatou
# Processing city 287: zhuanghe
# Processing city 288: benjamin hill
# Processing city 289: coracora
# Processing city 290: lorengau
# Processing city 291: sao filipe
# Processing city 292: outlook
# Processing city 293: taltal
# City not found, skipping ust-kamchatsk
# Processing city 294: port moresby
# Processing city 295: gazimurskiy zavod
# Processing city 296: minot
# Processing city 297: obuasi
# Processing city 298: abaza
# Processing city 299: crailsheim
# Processing city 300: thung song
# Processing city 301: fare
# Processing city 302: khandyga
# Processing city 303: kattivakkam
# Processing city 304: carnarvon
# Processing city 305: hamilton
# Processing city 306: ketchikan
# Processing city 307: salinas
# Processing city 308: mapastepec
# Processing city 309: huainan
# Processing city 310: tucupita
# Processing city 311: saint-georges
# City not found, skipping manzil jamil
# Processing city 312: tazovskiy
# Processing city 313: oldenburg
# City not found, skipping vaitupu
# Processing city 314: garowe
# Processing city 315: pevek
# Processing city 316: rialma
# Processing city 317: sirnak
# Processing city 318: tessaoua
# Processing city 319: klaksvik
# Processing city 320: madinat sittah uktubar
# Processing city 321: touros
# Processing city 322: goranboy
# Processing city 323: grand-lahou
# Processing city 324: havoysund
# Processing city 325: french harbor
# Processing city 326: nata
# City not found, skipping balykshi
# Processing city 327: rawson
# Processing city 328: xining
# Processing city 329: roald
# Processing city 330: port hawkesbury
# Processing city 331: texarkana
# Processing city 332: nemuro
# Processing city 333: gazanjyk
# Processing city 334: witu
# Processing city 335: coquimbo
# Processing city 336: te anau
# Processing city 337: akyab
# Processing city 338: maceio
# Processing city 339: gamba
# Processing city 340: arifwala
# Processing city 341: flinders
# Processing city 342: quelimane
# Processing city 343: san rafael
# Processing city 344: matara
# Processing city 345: guerrero negro
# Processing city 346: hay river
# Processing city 347: potsdam
# Processing city 348: labuhan
# Processing city 349: mantua
# Processing city 350: champerico
# Processing city 351: saint-francois
# Processing city 352: trinidad
# Processing city 353: acapulco
# Processing city 354: dudinka
# Processing city 355: petropavlovsk-kamchatskiy
# Processing city 356: ndele
# Processing city 357: pandan niog
# Processing city 358: laguna
# Processing city 359: visnes
# Processing city 360: umm kaddadah
# City not found, skipping samusu
# Processing city 361: shelburne
# City not found, skipping shchuchye
# Processing city 362: desaguadero
# Processing city 363: nishihara
# Processing city 364: saa
# Processing city 365: ca mau
# Processing city 366: portland
# Processing city 367: matagami
# Processing city 368: subkhankulovo
# Processing city 369: lamu
# City not found, skipping labutta
# Processing city 370: bartica
# Processing city 371: riyadh
# Processing city 372: gohpur
# Processing city 373: nome
# Processing city 374: san carlos
# Processing city 375: kutum
# City not found, skipping grand centre
# Processing city 376: belaya gora
# Processing city 377: dourbali
# Processing city 378: miles city
# Processing city 379: manta
# City not found, skipping yomitan
# Processing city 380: beysehir
# Processing city 381: zhanaozen
# Processing city 382: sakakah
# Processing city 383: barra patuca
# Processing city 384: bulgan
# Processing city 385: kichera
# City not found, skipping grand river south east
# Processing city 386: arman
# Processing city 387: sudbury
# Processing city 388: russell
# Processing city 389: kapit
# Processing city 390: kampot
# Processing city 391: hami
# Processing city 392: masuda
# Processing city 393: goderich
# Processing city 394: macherla
# Processing city 395: mananara
# Processing city 396: estacion coahuila
# Processing city 397: urumqi
# Processing city 398: san felipe
# Processing city 399: caraquet
# Processing city 400: cruz alta
# Processing city 401: zwedru
# Processing city 402: aquiraz
# City not found, skipping attawapiskat
# Processing city 403: paka
# Processing city 404: kaeo
# Processing city 405: pierre
# Processing city 406: kuznechikha
# Processing city 407: kharp
# Processing city 408: porto nacional
# Processing city 409: pindwara
# Processing city 410: eqbaliyeh
# Processing city 411: valparaiso
# Processing city 412: masty
# Processing city 413: savyntsi
# Processing city 414: severo-yeniseyskiy
# Processing city 415: nizhniy baskunchak
# Processing city 416: richards bay
# Processing city 417: sardinia
# Processing city 418: morros
# Processing city 419: bitkine
# Processing city 420: porto empedocle
# Processing city 421: buala
# Processing city 422: chapais
# Processing city 423: quincy
# Processing city 424: timmins
# Processing city 425: tazmalt
# City not found, skipping bargal
# Processing city 426: paamiut
# Processing city 427: puerto leguizamo
# Processing city 428: nantucket
# Processing city 429: buraydah
# Processing city 430: khorramabad
# Processing city 431: swift current
# Processing city 432: leningradskiy
# Processing city 433: nuzvid
# Processing city 434: soyo
# Processing city 435: mehamn
# City not found, skipping paradwip
# Processing city 436: tabanan
# Processing city 437: agadez
# Processing city 438: kargopol
# Processing city 439: krasnouralsk
# Processing city 440: sholokhove
# Processing city 441: faanui
# Processing city 442: muhos
# Processing city 443: campos novos
# Processing city 444: bogalusa
# Processing city 445: porto novo
# Processing city 446: pudozh
# Processing city 447: piacabucu
# Processing city 448: haines junction
# Processing city 449: kismayo
# Processing city 450: northam
# Processing city 451: norman wells
# Processing city 452: jalu
# Processing city 453: rock sound
# Processing city 454: acatic
# Processing city 455: chanika
# Processing city 456: dobryanka
# Processing city 457: tilichiki
# Processing city 458: beringovskiy
# Processing city 459: saravan
# City not found, skipping tubruq
# Processing city 460: kocevje
# Processing city 461: shingu
# Processing city 462: tocopilla
# Processing city 463: kurunegala
# Processing city 464: fukue
# Processing city 465: khasan
# Processing city 466: nago
# Processing city 467: nyurba
# City not found, skipping haibowan
# Processing city 468: mahajanga
# Processing city 469: onega
# Processing city 470: saint-augustin
# Processing city 471: vung tau
# Processing city 472: mareeba
# Processing city 473: makurdi
# Processing city 474: marsh harbour
# Processing city 475: hede
# Processing city 476: scarborough
# Processing city 477: olinda
# City not found, skipping golcuk
# Processing city 478: cilegon
# Processing city 479: wilkie
# City not found, skipping obluche
# Processing city 480: peniche
# City not found, skipping tuggurt
# Processing city 481: husavik
# Processing city 482: freeport
# Processing city 483: qui nhon
# Processing city 484: la ronge
# Processing city 485: general roca
# Processing city 486: poum
# Processing city 487: tagusao
# Processing city 488: vao
# Processing city 489: hoi an
# Processing city 490: almeria
# Processing city 491: bijie
# Processing city 492: hirara
# Processing city 493: alta
# Processing city 494: juneau
# Processing city 495: tanete
# Processing city 496: atar
# Processing city 497: inta
# Processing city 498: launceston
# Processing city 499: los llanos de aridane
# Processing city 500: port lincoln
# Processing city 501: bagarji
# Processing city 502: salamanca
# Processing city 503: hanting
# Processing city 504: mana
# Processing city 505: siva
# City not found, skipping dzhusaly
# Processing city 506: edea
# Processing city 507: la pila
# Processing city 508: okhotsk
# Processing city 509: consett
# Processing city 510: naucalpan
# Processing city 511: oliver
# Processing city 512: caraguatatuba
# Processing city 513: aripuana
# Processing city 514: shenjiamen
# Processing city 515: swakopmund
# Processing city 516: cairns
# Processing city 517: dekar
# Processing city 518: alugan
# Processing city 519: monrovia
# Processing city 520: bathsheba
# Processing city 521: aswan
# Processing city 522: weligama
# Processing city 523: denpasar
# Processing city 524: madimba
# Processing city 525: victoria
# Processing city 526: port hedland
# Processing city 527: taksimo
# Processing city 528: zaraza
# City not found, skipping safwah
# Processing city 529: sibolga
# Processing city 530: doha
# Processing city 531: aklavik
# Processing city 532: muromtsevo
# Processing city 533: san quintin
# Processing city 534: ucluelet
# Processing city 535: barre
# Processing city 536: tessalit
# Processing city 537: matinhos
# Processing city 538: veraval
# City not found, skipping yirol
# Processing city 539: mounana
# Processing city 540: anadyr
# Processing city 541: turayf
# Processing city 542: ischia
# Processing city 543: oktyabrskoye
# Processing city 544: vila franca do campo
# Processing city 545: vila velha
# Processing city 546: zaysan
# Processing city 547: calugareni
# Processing city 548: leh
# Processing city 549: tambura
# Processing city 550: missoula
# Processing city 551: pingliang
# Processing city 552: road town
# Processing city 553: bima
# Processing city 554: ola
# Processing city 555: rio cuarto
# Processing city 556: palmerston north
# Processing city 557: fort nelson
# Processing city 558: nicoya
# Processing city 559: zabid
# Processing city 560: yar-sale
# Processing city 561: celestun
# Processing city 562: jiangyou
# City not found, skipping ngukurr
# Processing city 563: faya
# Processing city 564: flin flon
# Processing city 565: rodeo
# Processing city 566: myre
# Processing city 567: carballo
# Processing city 568: great yarmouth
# Processing city 569: dvinskoy
# Processing city 570: altamira
# Processing city 571: mapiripan
# Processing city 572: sabalgarh

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = pd.DataFrame({
    "Origin" : new_cities,
    "Lat" : latitude, 
    "Long" : longitude,
    "Max Temp (F)" : max_temperature,
    "Humidity %" : humidity_pct,
    "Cloudiness %" : cloudiness_pct,
    "Wind Speed (mph)" : wind_speed_mph,
    "Date" : date
})

# %%
weather_data
# Out:
#              Origin    Lat    Long  Max Temp (F)  Humidity %  Cloudiness %  \
# 0       clyde river  70.47  -68.59         15.80          85            75
# 1             ancud -41.87  -73.82         59.00          87            20
# 2      puerto ayora  -0.74  -90.35         84.20          74            40
# 3         geraldton -28.77  114.60         68.00          82            90
# 4               shu  43.60   73.76         53.26          36             0
# ..              ...    ...     ...           ...         ...           ...
# 567  great yarmouth  52.61    1.73         48.00          99            98
# 568        dvinskoy  62.15   45.12         31.71          95            94
# 569        altamira  -3.20  -52.21         87.80          58            75
# 570       mapiripan   2.89  -72.13         76.50          79            98
# 571       sabalgarh  26.25   77.40         87.66          14            29
#
#      Wind Speed (mph)        Date
# 0                4.70  1587233714
# 1                9.17  1587233714
# 2               13.87  1587233714
# 3               10.29  1587233715
# 4                6.62  1587233682
# ..                ...         ...
# 567              1.99  1587233820
# 568              1.72  1587233821
# 569              3.36  1587233821
# 570              7.56  1587233821
# 571              5.57  1587233821
#
# [572 rows x 8 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_100 = weather_data["Origin"].loc[weather_data["Humidity %"] > 100]
if humidity_100.count() > 0:
    print(f"There are {humidity_100.count()} cities that have over 100% humidity. The cities have been removed.")
    humid_data = weather_data.loc[weather_data["Humidity %"] <= 100]
    print(humidity_100)
    
else: print(f"There are no cities with over 100% humidity.")
# Out:
# There are no cities with over 100% humidity.

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_100_plus = weather_data["Origin"].loc[weather_data["Humidity %"] > 100]
if humidity_100.count() > 0:
    print(f"There are {humidity_100.count()} cities that have over 100% humidity. The cities have been removed.")
    humid_data = weather_data.loc[weather_data["Humidity %"] >= 100]
    print(humidity_100_plus)
    
else: print(f"There are no cites with over 100% humidity.")
# Out:
# There are no cites with over 100% humidity.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.

# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(latitude, max_temperature, c="red",edgecolors="blue")
plt.title("Latitude vs Temperature (F)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.show()
plt.savefig("../Images/LatitudevTemperature")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(latitude, humidity_pct,c="green",edgecolors="gold")
plt.title("Latitude vs Humidity (%)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.show()
plt.savefig("../Images/LatitudevHumidity")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(latitude, cloudiness_pct,c="maroon",edgecolors="gold")
plt.title("Latitude vs Cloudiness (%)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.show()
plt.savefig("../Images/LatitudevCloudiness")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(latitude, wind_speed_mph,c="gold",edgecolors="purple")
plt.title("Latitude vs Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.grid()
plt.show()
plt.savefig("../Images/LatitudevWindSpeed")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_data = weather_data.loc[weather_data["Lat"] > 0]
southern_data = weather_data.loc[weather_data["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(northern_data["Max Temp (F)"], northern_data["Lat"],c="maroon",edgecolors="gold")
plt.title("Northern Hemisphere Max Temperature (F) vs Latitude")
plt.ylabel("Latitude")
plt.xlabel("Max Temperature (F)")
plt.grid()
plt.show()

x_values = northern_data["Max Temp (F)"]
y_values = northern_data["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,c="maroon",edgecolors="gold")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.title("Northern Hemisphere Max Temperature (F) vs Latitude (Linear Regression)")
plt.ylabel("Latitude")
plt.xlabel("Max Temperature (F)")
plt.grid()
plt.show()
plt.savefig("../Images/NH Temp vs Latitude")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(southern_data["Max Temp (F)"], southern_data["Lat"],c="green",edgecolors="gold")
plt.title("Southern Hemisphere Max Temperature (F) vs Latitude")
plt.ylabel("Latitude")
plt.xlabel("Max Temperature (F)")
plt.grid()
plt.show()

x_values = southern_data["Max Temp (F)"]
y_values = southern_data["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,c="green",edgecolors="gold")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.title("Southern Hemisphere Max Temperature (F) vs Latitude (Linear Regression)")
plt.ylabel("Latitude")
plt.xlabel("Max Temperature (F)")
plt.grid()
plt.show()
plt.savefig("../Images/SH Temp vs Latitude")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(northern_data["Humidity %"], northern_data["Lat"],c="maroon",edgecolors="gold")
plt.title("Northern Hemisphere Humidity (%) vs Latitude")
plt.ylabel("Latitude")
plt.xlabel("Humidity (%)")
plt.grid()
plt.show()

x_values = northern_data["Humidity %"]
y_values = northern_data["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,c="maroon",edgecolors="gold")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.title("Northern Hemisphere Humidity (%) vs Latitude (Linear Regression)")
plt.ylabel("Latitude")
plt.xlabel("Humidity (%)")
plt.grid()
plt.show()
plt.savefig("../Images/NH Humidity vs Latitude")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(southern_data["Humidity %"], southern_data["Lat"],c="green",edgecolors="gold")
plt.title("Southern Hemisphere Humidity (%) vs Latitude")
plt.ylabel("Latitude")
plt.xlabel("Humidity %")
plt.grid()
plt.show()

x_values = southern_data["Humidity %"]
y_values = southern_data["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,c="green",edgecolors="gold")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.title("Southern Hemisphere Humidity (%) vs Latitude (Linear Regression)")
plt.ylabel("Latitude")
plt.xlabel("Humidity %")
plt.grid()
plt.show()
plt.savefig("../Images/SH Humidity vs Latitude")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(northern_data["Cloudiness %"], northern_data["Lat"],c="maroon",edgecolors="gold")
plt.title("Northern Hemisphere Cloudiness (%) vs Latitude")
plt.ylabel("Latitude")
plt.xlabel("Cloudiness (%)")
plt.grid()
plt.show()

x_values = northern_data["Cloudiness %"]
y_values = northern_data["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,c="maroon",edgecolors="gold")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.title("Northern Hemisphere Cloudiness (%) vs Latitude (Linear Regression)")
plt.ylabel("Latitude")
plt.xlabel("Cloudiness (%)")
plt.grid()
plt.show()
plt.savefig("../Images/NH Cloudiness vs Latitude")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(southern_data["Cloudiness %"], southern_data["Lat"],c="green",edgecolors="gold")
plt.title("Southern Hemisphere Humidity (%) vs Latitude")
plt.ylabel("Latitude")
plt.xlabel("Cloudiness (%)")
plt.grid()
plt.show()

x_values = southern_data["Cloudiness %"]
y_values = southern_data["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,c="green",edgecolors="gold")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.title("Southern Hemisphere Humidity (%) vs Latitude (Linear Regression)")
plt.ylabel("Latitude")
plt.xlabel("Cloudiness (%)")
plt.grid()
plt.show()
plt.savefig("../Images/SH Cloudiness vs Latitude")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(northern_data["Wind Speed (mph)"], northern_data["Lat"],c="maroon",edgecolors="gold")
plt.title("Northern Hemisphere Wind Speed (mph) vs Latitude")
plt.ylabel("Latitude")
plt.xlabel("Wind Speed (mph)")
plt.grid()
plt.show()

x_values = northern_data["Wind Speed (mph)"]
y_values = northern_data["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,c="maroon",edgecolors="gold")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.title("Northern Hemisphere Wind Speed (mph) vs Latitude (Linear Regression)")
plt.ylabel("Latitude")
plt.xlabel("Wind Speed (mph)")
plt.grid()
plt.show()
plt.savefig("../Images/NH Wind Speed vs Latitude")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(southern_data["Wind Speed (mph)"], southern_data["Lat"],c="green",edgecolors="gold")
plt.title("Southern Hemisphere Wind Speed (mph) vs Latitude")
plt.ylabel("Latitude")
plt.xlabel("Wind Speed (mph)")
plt.grid()
plt.show()

x_values = southern_data["Wind Speed (mph)"]
y_values = southern_data["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,c="green",edgecolors="gold")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.title("Southern Hemisphere Wind Speed (mph) vs Latitude (Linear Regression)")
plt.ylabel("Latitude")
plt.xlabel("Wind Speed (mph)")
plt.grid()
plt.show()
plt.savefig("../Images/SH Wind Speed vs Latitude")

# %%
weather_data.to_csv("../Images/cities.csv")
